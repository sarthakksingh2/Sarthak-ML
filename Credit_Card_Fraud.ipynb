# %% [markdown]
# <a href="https://colab.research.google.com/github/sarthakksingh2/Sarthak-ML/blob/main/Credit_Card_Fraud.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
credited_card_df = pd.read_csv('creditcard.csv')

# %%
credited_card_df.head()
# Out:
#       Time        V1        V2        V3        V4        V5        V6  \
# 5665  5921 -2.229818  2.247262  0.616172 -0.075552 -0.696383 -0.307728
# 3684  3143 -3.694439  0.420388  0.619713 -0.849952  1.114947 -0.062059
# 4638  4013  0.396462 -1.061374 -0.143748 -3.573015 -0.763387  0.578597
# 6855  8715 -0.447418  0.424726  3.214006  3.781284 -1.266217  1.173467
# 6848  8688  1.393336 -0.749140  0.963299 -0.599487 -1.155472  0.315264
#
#             V7        V8        V9  ...       V21       V22       V23  \
# 5665 -0.320726  0.904834  1.078978  ... -0.247700 -0.621363  0.188980
# 3684  1.102801 -1.183754  1.047685  ... -0.385597 -0.589252 -0.032500
# 4638 -0.417008 -0.796022  2.204338  ...  0.422330 -0.516262  0.228554
# 6855 -0.798863  0.321206  1.812212  ...  0.101545  1.093534 -0.012159
# 6848 -1.432903  0.177104  1.116584  ...  0.138847  0.673284 -0.187811
#
#            V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
credited_card_df.shape
# Out:
# (13954, 31)

# %%
credited_card_df['Class'].value_counts()
# Out:
# Class
# 0.0    13897
# 1.0       56
# Name: count, dtype: int64

# %% [markdown]
# where, 1 : Fraud Transaction & 0 : Legitamate Transaction

# %%
credited_card_df.describe()
# Out:
#                Time            V1            V2            V3            V4  \
# count  13954.000000  13954.000000  13954.000000  13954.000000  13954.000000
# mean   10121.161817     -0.235676      0.284287      0.846047      0.302775
# std     7739.625811      1.720315      1.394804      1.561376      1.500595
# min        0.000000    -27.670569    -34.607649    -24.667741     -4.657545
# 25%     2984.250000     -0.969786     -0.282728      0.407297     -0.623141
# 50%     9086.500000     -0.319439      0.252904      0.960978      0.220104
# 75%    17103.500000      1.162662      0.884741      1.607031      1.198942
# max    24759.000000      1.960497     10.558600      4.101716     11.927512
#
#                  V5            V6            V7            V8            V9  \
# count  13954.000000  13954.000000  13954.000000  13954.000000  13954.000000
# mean      -0.118730      0.128013     -0.157297     -0.016148      0.989827
# ...

# %%
legit = credited_card_df[credited_card_df.Class == 0]
fraud = credited_card_df[credited_card_df.Class == 1]

# %%
fraud.shape
# Out:
# (56, 31)

# %%
legit.shape
# Out:
# (13897, 31)

# %%
legit_sample = legit.sample(n=492)
credited_card_df = pd.concat([legit_sample, fraud], axis=0)

# %%
credited_card_df['Class'].value_counts()
# Out:
# Class
# 0.0    492
# 1.0     56
# Name: count, dtype: int64

# %%
credited_card_df.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0.0    10856.920732 -0.294937  0.305078  0.820501  0.260808 -0.092734
# 1.0    12262.107143 -4.727948  4.660436 -9.328536  6.783464 -2.890388
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.110527 -0.081220 -0.015479  1.108480  ...  0.045347 -0.068615
# 1.0   -2.030360 -6.578337  1.028374 -2.981468  ...  0.453283  0.116896
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.169297 -0.018045 -0.001357  0.130543  0.029287  0.036124  0.004094
# 1.0    0.048132 -0.225526 -0.452514 -0.124184  0.333325  0.793484 -0.046177
#
#           Amount
# Class
# 0.0    65.891850
# 1.0    90.815893
#
# [2 rows x 30 columns]

# %%
x = credited_card_df.drop('Class', axis=1)
y = credited_card_df['Class']

# %%
x.shape
# Out:
# (548, 30)

# %%
y.shape
# Out:
# (548,)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, stratify=y, random_state=2)

# %%
model = LogisticRegression()
model.fit(x_train, y_train)
ypred = model.predict(x_test)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
score = accuracy_score(ypred,y_test)
print("Accuracy score on Test Data is ",score)
# Out:
# Accuracy score on Test Data is  0.9636363636363636

# %%
xpred = model.predict(x_train)
training_data_accuracy = accuracy_score(xpred,y_train)

# %%
print("Accuracy score on Training Data is ",training_data_accuracy)
# Out:
# Accuracy score on Training Data is  0.9863013698630136
